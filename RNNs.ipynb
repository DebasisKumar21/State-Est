# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme()

import torch 
import torch.nn as nn 
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.set_default_dtype(torch.float32)

# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# MLP Baseline
class ToyMLP(nn.Module):
    def __init__(self, input_size, output_size):
        super(ToyMLP, self).__init__()
        self.fc = nn.Sequential(nn.Linear(input_size, 128),
                                nn.ReLU(),
                                nn.Linear(128, 128),
                                nn.ReLU(),
                                nn.Linear(128, 128),
                                nn.ReLU(),
                                nn.Linear(128, 64), 
                                nn.ReLU(), 
                                nn.Linear(64, 32),
                                nn.ReLU(),
                                nn.Linear(32, output_size)
                                )    
    def forward(self, x):
        out = self.fc(x)
        return out
    
# LSTM Baseline
class ToyLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ToyLSTM, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.lstm = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=2, batch_first=True)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, output_size)
        self.activation = nn.ReLU()
    
    def forward(self, x):
        batch_size = x.shape[0]
        out = self.activation(self.linear1(x))
        _, (hn, cn) = self.lstm(out.view(batch_size, 1, -1))
        out = self.activation(self.linear2(hn[0]))
        out = self.linear3(out)
        return out 
    
# GRU Baseline
class ToyGRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ToyGRU, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.gru = nn.GRU(input_size=hidden_size, hidden_size=hidden_size, num_layers=2,batch_first=True)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, output_size)
        self.activation = nn.ReLU()
    
    def forward(self, x):
        batch_size = x.shape[0]
        out = self.activation(self.linear1(x))
        _, hn = self.gru(out.view(batch_size, 1, -1))
        out = self.activation(self.linear2(hn[0]))
        out = self.linear3(out)
        return out
    
# Expressive LSTM
class ProLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ProLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=2, bidirectional=True, batch_first=True)
        self.linear1 = nn.Linear(hidden_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, output_size)
        self.activation = nn.PReLU()
    
    def forward(self, x):
        batch_size = x.shape[0]
        out, (hn, cn) = self.lstm(x.view(batch_size, 1, -1))
        out = self.activation(self.linear1(hn[0])) # self.linear1(out)
        out = self.activation(self.linear2(out))
        out = self.linear3(out)
        return out
    
# Expressive LSTM v2
class ProLSTM2(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ProLSTM2, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=2, bidirectional=True, batch_first=True)
        self.linear1 = nn.Linear(hidden_size, hidden_size) # nn.Linear(hidden_size * 2, hidden_size) for self lstm_out
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, output_size)
        self.activation = nn.PReLU()
    
    def forward(self, x):
        batch_size = x.shape[0]
        h0 = torch.zeros((4, batch_size, 512), device=device, requires_grad=True)
        c0 = torch.zeros((4, batch_size, 512), device=device, requires_grad=True)
        out, (hn, cn) = self.lstm(x.view(batch_size, 1, -1), (h0, c0))
        out = self.activation(self.linear1(hn[0]))
        # out = self.activation(self.linear1(out.view(batch_size, -1))) # self.linear1(hn[0])
        out = self.activation(self.linear2(out))
        out = self.linear3(out)
        return out
    
# Expressive GRU
class ProGRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ProGRU, self).__init__()
        self.lstm = nn.GRU(input_size=input_size, hidden_size=hidden_size, num_layers=2, bidirectional=True, batch_first=True)
        self.linear1 = nn.Linear(hidden_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, output_size)
        self.activation = nn.PReLU()
    
    def forward(self, x):
        batch_size = x.shape[0]
        out, hn = self.lstm(x.view(batch_size, 1, -1))
        out = self.activation(self.linear1(hn[0])) # self.linear1(out)
        out = self.activation(self.linear2(out))
        out = self.linear3(out)
        return out

# %%
# Custom Dataset Loader 
class TrajDataset(Dataset):
    """Expert Trajectory Dataset."""
    def __init__(self, data):
        
        # Inputs
        self.x = data[:, :-1]
        
        # Output
        self.y = data[:, -1]
        
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        
        # Inputs
        inp = self.x[idx]
        inp = inp.flatten()
        
        # Outputs
        out = self.y[idx]
        out = out.flatten()
        
        return torch.tensor(inp).float(), torch.tensor(out).float()

# Load the dataset
filetype = '_3_withpos'
train_data = np.load("./Dataset/train_data" + filetype + ".npy")
val_data = np.load("./Dataset/val_data" + filetype + ".npy")
test_data = np.load("./Dataset/test_data" + filetype + ".npy")

# Using PyTorch Dataloader
train_dataset = TrajDataset(train_data)
val_dataset = TrajDataset(val_data)
test_dataset = TrajDataset(test_data)

train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=0)

# %%
for batch_num, (datas) in enumerate(train_loader):
    inp, out = datas
    print(inp.shape, out.shape)
    break
# Out:
# torch.Size([512, 18]) torch.Size([512, 1])

# %%
# ToyMLP Inputs
input_size = 18
hidden_size = 512
output_size = 1

epochs = 150
model = ProLSTM2(input_size, hidden_size, output_size).to(device)
optimizer = optim.AdamW(model.parameters(), lr = 6e-3)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 15, gamma = 0.1)
loss_fn = nn.MSELoss()

avg_train_loss, avg_val_loss = [], []
for epoch in range(epochs):

    # Train Loop
    losses_train = []
    model.train()
    for inp, out in train_loader:

        inp = inp.to(device)
        out = out.to(device)

        # Forward Pass
        pred = model(inp)
        loss = loss_fn(pred, out)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses_train.append(loss.detach().cpu().numpy())

    # Test Loop
    losses_val = []
    model.eval()
    for inp, out in val_loader:

        inp = inp.to(device)
        out = out.to(device)

        # No Gradients
        with torch.no_grad():
            pred = model(inp)
            test_loss = loss_fn(pred, out)

        losses_val.append(test_loss.detach().cpu().numpy())

    print(f"Epoch: {epoch + 1}, Train Loss: {np.average(losses_train):.3f},  Val Loss: {np.average(losses_val):.3f}")

    scheduler.step()
    avg_train_loss.append(np.average(losses_train)), avg_val_loss.append(np.average(losses_val))
# Out:
# Epoch: 1, Train Loss: 0.113,  Val Loss: 0.092
# Epoch: 2, Train Loss: 0.085,  Val Loss: 0.095
# Epoch: 3, Train Loss: 0.078,  Val Loss: 0.086
# Epoch: 4, Train Loss: 0.074,  Val Loss: 0.076
# Epoch: 5, Train Loss: 0.067,  Val Loss: 0.078
# Epoch: 6, Train Loss: 0.064,  Val Loss: 0.075
# Epoch: 7, Train Loss: 0.060,  Val Loss: 0.066
# Epoch: 8, Train Loss: 0.060,  Val Loss: 0.064
# Epoch: 9, Train Loss: 0.057,  Val Loss: 0.059
# Epoch: 10, Train Loss: 0.055,  Val Loss: 0.059
# Epoch: 11, Train Loss: 0.052,  Val Loss: 0.057
# Epoch: 12, Train Loss: 0.050,  Val Loss: 0.056
# Epoch: 13, Train Loss: 0.049,  Val Loss: 0.056
# Epoch: 14, Train Loss: 0.048,  Val Loss: 0.056
# Epoch: 15, Train Loss: 0.045,  Val Loss: 0.054
# Epoch: 16, Train Loss: 0.040,  Val Loss: 0.047
# Epoch: 17, Train Loss: 0.038,  Val Loss: 0.047
# Epoch: 18, Train Loss: 0.037,  Val Loss: 0.046
# Epoch: 19, Train Loss: 0.036,  Val Loss: 0.045
# Epoch: 20, Train Loss: 0.036,  Val Loss: 0.045
# Epoch: 21, Train Loss: 0.035,  Val Loss: 0.044
# Epoch: 22, Train Loss: 0.034,  Val Loss: 0.044
# Epoch: 23, Train Loss: 0.033,  Val Loss: 0.043
# Epoch: 24, Train Loss: 0.033,  Val Loss: 0.043
# Epoch: 25, Train Loss: 0.032,  Val Loss: 0.042
# Epoch: 26, Train Loss: 0.032,  Val Loss: 0.042
# Epoch: 27, Train Loss: 0.031,  Val Loss: 0.042
# Epoch: 28, Train Loss: 0.030,  Val Loss: 0.041
# Epoch: 29, Train Loss: 0.030,  Val Loss: 0.042
# Epoch: 30, Train Loss: 0.029,  Val Loss: 0.040
# Epoch: 31, Train Loss: 0.028,  Val Loss: 0.040
# Epoch: 32, Train Loss: 0.028,  Val Loss: 0.040
# Epoch: 33, Train Loss: 0.027,  Val Loss: 0.041
# Epoch: 34, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 35, Train Loss: 0.027,  Val Loss: 0.041
# Epoch: 36, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 37, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 38, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 39, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 40, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 41, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 42, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 43, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 44, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 45, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 46, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 47, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 48, Train Loss: 0.027,  Val Loss: 0.040
# Epoch: 49, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 50, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 51, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 52, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 53, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 54, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 55, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 56, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 57, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 58, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 59, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 60, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 61, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 62, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 63, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 64, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 65, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 66, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 67, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 68, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 69, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 70, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 71, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 72, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 73, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 74, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 75, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 76, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 77, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 78, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 79, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 80, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 81, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 82, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 83, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 84, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 85, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 86, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 87, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 88, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 89, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 90, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 91, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 92, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 93, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 94, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 95, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 96, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 97, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 98, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 99, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 100, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 101, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 102, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 103, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 104, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 105, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 106, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 107, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 108, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 109, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 110, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 111, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 112, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 113, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 114, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 115, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 116, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 117, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 118, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 119, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 120, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 121, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 122, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 123, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 124, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 125, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 126, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 127, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 128, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 129, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 130, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 131, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 132, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 133, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 134, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 135, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 136, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 137, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 138, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 139, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 140, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 141, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 142, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 143, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 144, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 145, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 146, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 147, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 148, Train Loss: 0.026,  Val Loss: 0.040
# Epoch: 149, Train Loss: 0.026,  Val Loss: 0.039
# Epoch: 150, Train Loss: 0.026,  Val Loss: 0.040

# %%
e = np.arange(epoch+1)

plt.figure( figsize=(12, 8))
plt.plot(e, np.array(avg_train_loss), label="Train Loss", color="green")
plt.plot(e, np.array(avg_val_loss), label="Val Loss", color="orange")
plt.legend(loc=1 ,prop={'size': 12})
# plt.ylim([0, 30])
plt.xlabel("Epochs")
plt.ylabel("Average Loss")
plt.show()

# %%
torch.save(model.state_dict(), './Weights/weights_lstmv2' + filetype + '.pth')

# %%
# Load the Test Dataset
test_set = torch.from_numpy(test_data)

# Feature and Ground Truth Matrix
X = test_set[:, :-1].to(device)
y = test_set[:, -1].reshape(-1, 1).to(device)

# Inference
with torch.no_grad():
    model.eval()
    test_pred = model(X)

test_loss = loss_fn(test_pred, y)    

print(f"Test MSE Loss: {test_loss:.3f}")

test_set.shape, X.shape, y.shape, test_pred.shape
# Out:
# Test MSE Loss: 0.039
# (torch.Size([5375, 19]),
#  torch.Size([5375, 18]),
#  torch.Size([5375, 1]),
#  torch.Size([5375, 1]))

# %%
t = np.linspace(0, X.shape[0], X.shape[0])*0.05

# %matplotlib qt
plt.figure( figsize=(18, 12))
plt.plot(t, y.cpu().numpy(), label="Ground Truth", color="blue")
plt.plot(t, test_pred.cpu().numpy(), label="Predictions", color="orange")
plt.legend(loc=1 ,prop={'size': 12})
plt.xlim(0, 5)
# plt.ylim(-10, 10)
plt.xlabel("t")
plt.ylabel("Angular Velocity")
# plt.savefig("GRU Predictions.png")
plt.show()
